# %%
# -*- coding: utf-8 -*-
"""Multiple_LR_HomePrice.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1fK78C8TPV44HdvT6lsMhaau2wMtKXquQ
"""

import pandas as pd
import numpy as np
from sklearn import linear_model

df = pd.read_csv('/content/homeprices_Multiple_LR.csv')
df

"""Data Preprocessing: Fill NA values with median value of a column"""

df.bedrooms.median()

df.bedrooms = df.bedrooms.fillna(df.bedrooms.median())
df

reg = linear_model.LinearRegression()
reg.fit(df.drop('price',axis='columns'),df.price)

reg.coef_

reg.intercept_

"""Find price of home with 3000 sqr ft area, 3 bedrooms, 40 year old"""

reg.predict([[3000, 3, 40]])

112.06244194*3000 + 23388.88007794*3 + -3231.71790863*40 + 221323.00186540384
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 498408.25157402386

# %%
# -*- coding: utf-8 -*-
"""Linear-Regression-Housing_Area_Price.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1CAlZml-P6V2V1RIrodgMfF8L3Ux4V9FT
"""

import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

df = pd.read_csv('/content/housing_area_price.csv')
df

# Commented out IPython magic to ensure Python compatibility.
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker='+')

new_df = df.drop('price',axis='columns')
new_df

price = df.price
price

# Create linear regression object
reg = linear_model.LinearRegression()
reg.fit(new_df,price)

"""(1) Predict price of a home with area = 3300 sqr ft"""

reg.predict([[3300]])

reg.coef_

reg.intercept_

"""Y = m * X + b (m is coefficient and b is intercept)"""

3300*135.78767123 + 180616.43835616432

"""(1) Predict price of a home with area = 5000 sqr ft"""

reg.predict([[5000]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
df = pd.read_csv('/content/canada_per_capita_income.csv')
df
new_df = df.drop('per capita income (US$)',axis='columns')
new_df
per_capita_income = y = df['per capita income (US$)'].values
reg = linear_model.LinearRegression()
reg.fit(new_df,per_capita_income)
print("predicted per capita income in 2020:",reg.predict([[2020]]))
print("coeff:" ,reg.coef_)
print("intercept:" ,reg.intercept_)
# Plotting the data points and regression line
plt.scatter(df['year'], per_capita_income, color='blue', label='Data Points')
plt.plot(df['year'], reg.predict(new_df), color='red', label='Regression Line')

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Per Capita Income (US$)')
plt.title('Regression Line: Per Capita Income vs Year')
plt.legend()

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# predicted per capita income in 2020: [41288.69409442]
# coeff: [828.46507522]
# intercept: -1632210.7578554575

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
df = pd.read_csv('/content/salary.csv')
df.YearsExperience.median()

df.YearsExperience = df.YearsExperience.fillna(df.YearsExperience.median())
print(df.to_string(index=False))
new_df = df.drop('Salary',axis='columns')
salary = df['Salary'].values
reg = linear_model.LinearRegression()
reg.fit(new_df,salary)
print("predicted Salary with 12 years experience: ",reg.predict([[12]]))
print("coeff:" ,reg.coef_)
print("intercept:" ,reg.intercept_)
# Out:
#  YearsExperience  Salary
#              1.1   39343
#              1.3   46205
#              1.5   37731
#              2.0   43525
#              2.2   39891
#              2.9   56642
#              3.0   60150
#              3.2   54445
#              3.2   64445
#              3.7   57189
#              3.9   63218
#              4.0   55794
#              4.0   56957
#              4.1   57081
#              4.5   61111
#              4.9   67938
#              5.1   66029
#              5.3   83088
#              5.9   81363
#              6.0   93940
#              6.8   91738
#              7.1   98273
#              7.9  101302
#              8.2  113812
#              8.7  109431
#              9.0  105582
#              4.5  116969
#              9.6  112635
#             10.3  122391
#             10.5  121872
# predicted Salary with 12 years experience:  [139574.04095966]
# coeff: [9275.93010112]
# intercept: 28262.879746248997
# ...

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

df = pd.read_csv('/content/hiring.csv')
experience_map = {
    'one': 1,
    'two': 2,
    'three': 3,
    'four': 4,
    'five': 5,
    'six': 6,
    'seven': 7,
    'eight': 8,
    'nine': 9,
    'ten': 10,
    'eleven': 11,
    'twelve': 12
}
experience_map=df['experience'] = df['experience'].map(experience_map)
df.test_score = df.test_score.fillna(df.test_score.median())
df.experience = df.experience.fillna(df.experience.median())
print(df.to_string(index=False))
# new_df = df.drop('salary',axis='columns')
salary = df['salary'].values
reg = linear_model.LinearRegression()
reg.fit(df.drop('salary',axis='columns'),df.salary)
print("predicted Salary with 2 yr experience, 9 test score, 6 interview score: ",reg.predict([[2,9,6]]))
print("predicted Salary with 12 yr experience, 10 test score, 10 interview score: ",reg.predict([[12,10,10]]))
print("coeff:" ,reg.coef_)
print("intercept:" ,reg.intercept_)
# Out:
#  experience  test_score  interview_score  salary
#         6.0         8.0                9   50000
#         6.0         8.0                6   45000
#         5.0         6.0                7   60000
#         2.0        10.0               10   65000
#         7.0         9.0                6   70000
#         3.0         7.0               10   62000
#        10.0         8.0                7   72000
#        11.0         7.0                8   80000
# predicted Salary with 2 yr experience, 9 test score, 6 interview score:  [47056.91056911]
# predicted Salary with 12 yr experience, 10 test score, 10 interview score:  [88227.64227642]
# coeff: [2813.00813008 1333.33333333 2926.82926829]
# intercept: 11869.91869918695
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ...

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

df = pd.read_csv('/content/1000_Companies.csv')
experience_map = {
    'New York': 1,
    'California': 2,
    'Florida': 3,
}
experience_map=df['State'] = df['State'].map(experience_map)
# new_df = df.drop('salary',axis='columns')
salary = df['Profit'].values
reg = linear_model.LinearRegression()
reg.fit(df.drop('Profit',axis='columns'),df.Profit)
print("predicted Profit ",reg.predict([[91694.48,515841.3,11931.24,3]]))
print("coeff:" ,reg.coef_)
print("intercept:" ,reg.intercept_)
# Out:
# predicted Profit  [510745.17756471]
# coeff: [ 5.53204150e-01  1.02649898e+00  8.10242612e-02 -2.70789702e+02]
# intercept: -69645.50797651058
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
